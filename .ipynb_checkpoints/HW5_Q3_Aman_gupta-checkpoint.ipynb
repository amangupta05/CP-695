# %% [markdown]
# ## Homework starts below from  MSE function

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from numpy.random import randint
from numpy.random import rand

# %%
plt.style.use('seaborn-whitegrid') 
import numpy as np 
noise_scale = 100 
number_of_samples = 50 
x =  30*(np.random.rand(number_of_samples, 2) - 0.5) 
y = 5 * x + 15 * x**2 + 2 * x*3+ noise_scale*np.random.randn(number_of_samples, 1)

# %%
x1 = x.flatten(order='C')
y1 = y.flatten(order='C')

# %%
plt.plot(x1,y1,'ro')

# %% [markdown]
# Task 1

# %%
plt.style.use('seaborn-whitegrid') 
m=4
X=30*(np.random.rand(number_of_samples, 1) - 0.5)
Y= 5 * X + 15 * X**2 + 2 * X*3+ noise_scale*np.random.randn(number_of_samples, 1) 
poly=PolynomialFeatures(degree=m,include_bias=False)
poly_X=poly.fit_transform(X)
plt.plot(poly_X,Y,'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f86921b9400>,
#  <matplotlib.lines.Line2D at 0x7f86921b94c0>,
#  <matplotlib.lines.Line2D at 0x7f86921b95e0>,
#  <matplotlib.lines.Line2D at 0x7f86921b9700>]

# %% [markdown]
# Task 2

# %%
def MSE(x,y,m,noise_scale,number_of_samples):
    x1 = x.flatten(order='C')
    y1 = y.flatten(order='C')
    print('Plot with m = '+ str(m) +' and noise _scale = '+ str(noise_scale)+' and number_of_samples = '+str(number_of_samples))
    print('Data Points')
    plt.plot(x1,y1,'ro')
    plt.show()
    curve = np.polyfit(x1, y1,m)
    formula=np.poly1d(curve)
    print('Polynomial Equation : ')
    print(formula)
    new_x1=x1
    pred_y=[]
    for i in range(len(new_x1)):
        new_y=formula(new_x1[i])
        pred_y.append(new_y)
    print('Fit Line')
    plt.plot(new_x1,pred_y)
    plt.show()
    poly1d_fn = np.poly1d(curve) 
    print('Plot with original data points and best fit line')
    plt.plot(new_x1,y1, 'yo', new_x1, poly1d_fn(new_x1))
    plt.show()
    true_y=list(y1)
    MSE_df=pd.DataFrame()
    MSE_df['true_vals']=true_y
    MSE_df['pred_vals']=pred_y
    MSE_df['error_vals']=MSE_df['true_vals']-MSE_df['pred_vals']
    MSE_val=sum([val**2/len(MSE_df) for val in MSE_df['error_vals']])
    print('MSE val where m = '+str(m)+' and noise _scale = '+ str(noise_scale)+' and number_of_samples = '+str(number_of_samples))
    print(MSE_val)
    print('###############################################################################')
    return MSE_val

# %%
new_x = sorted((25*(np.random.rand(number_of_samples) - 0.5)))
x=np.reshape(new_x, (50, 1))
y = 5 * x + 15 * x**2 + 2 * x**3 + noise_scale*np.random.randn(number_of_samples, 1)

# %%
for i in m_vals:
    MSE_value=MSE(x,y,i,noise_scale,number_of_samples)
    all_m_vals[i]=MSE_value
all_m_vals
# Out:
# Plot with m = 2 and noise _scale = 100 and number_of_samples = 50
# Data Points
# Polynomial Equation :
#        2
# 13.27 x + 208.4 x + 177.1
# Fit Line
# Plot with original data points and best fit line
# MSE val where m = 2 and noise _scale = 100 and number_of_samples = 50
# 446836.25816401903
# ###############################################################################
# Plot with m = 3 and noise _scale = 100 and number_of_samples = 50
# Data Points
# Polynomial Equation :
#       3         2
# 2.04 x + 15.03 x + 3.41 x + 3.141
# Fit Line
# Plot with original data points and best fit line
# MSE val where m = 3 and noise _scale = 100 and number_of_samples = 50
# 11713.822308050254
# ###############################################################################
# Plot with m = 4 and noise _scale = 100 and number_of_samples = 50
# Data Points
# Polynomial Equation :
#           4         3         2
# -0.01138 x + 2.034 x + 16.66 x + 3.934 x - 25.62
# Fit Line
# Plot with original data points and best fit line
# MSE val where m = 4 and noise _scale = 100 and number_of_samples = 50
# 11317.28288173341
# ###############################################################################
# Plot with m = 5 and noise _scale = 100 and number_of_samples = 50
# Data Points
# Polynomial Equation :
#             5           4         3         2
# -0.0005339 x - 0.01225 x + 2.126 x + 16.79 x + 1.041 x - 28.43
# Fit Line
# Plot with original data points and best fit line
# MSE val where m = 5 and noise _scale = 100 and number_of_samples = 50
# 11280.76307573844
# ###############################################################################
# Plot with m = 6 and noise _scale = 100 and number_of_samples = 50
# Data Points
# Polynomial Equation :
#            6             5          4         3         2
# 8.511e-05 x - 0.0003367 x - 0.0304 x + 2.094 x + 17.75 x + 1.973 x - 37.13
# Fit Line
# Plot with original data points and best fit line
# MSE val where m = 6 and noise _scale = 100 and number_of_samples = 50
# 11254.796557829966
# ###############################################################################
# {2: 446836.25816401903,
#  3: 11713.822308050254,
#  4: 11317.28288173341,
#  5: 11280.76307573844,
#  6: 11254.796557829966}

# %% [markdown]
# genetic algorithm search

# %%
def objective(x):
    return x[0]**2.0 + x[1]**2.0


def decode(bounds, n_bits, bitstring):
    decoded = list()
    largest = 2**n_bits
    for i in range(len(bounds)):
        # extract the substring
        start, end = i * n_bits, (i * n_bits)+n_bits
        substring = bitstring[start:end]
        # convert bitstring to a string of chars
        chars = ''.join([str(s) for s in substring])
        # convert string to integer
        integer = int(chars, 2)
        # scale integer to desired range
        value = bounds[i][0] + (integer/largest) * (bounds[i][1] - bounds[i][0])
        # store
        decoded.append(value)
    return decoded


def selection(pop, scores, k=3):
    # first random selection
    selection_ix = randint(len(pop))
    for ix in randint(0, len(pop), k-1):
        # check if better (e.g. perform a tournament)
        if scores[ix] < scores[selection_ix]:
            selection_ix = ix
    return pop[selection_ix]


def crossover(p1, p2, r_cross):
    # children are copies of parents by default
    c1, c2 = p1.copy(), p2.copy()
    # check for recombination
    if rand() < r_cross:
        # select crossover point that is not on the end of the string
        pt = randint(1, len(p1)-2)
        # perform crossover
        c1 = p1[:pt] + p2[pt:]
        c2 = p2[:pt] + p1[pt:]
    return [c1, c2]


def mutation(bitstring, r_mut):
    for i in range(len(bitstring)):
        # check for a mutation
        if rand() < r_mut:
            # flip the bit
            bitstring[i] = 1 - bitstring[i]

# genetic algorithm
def genetic_algorithm(objective, bounds, n_bits, n_iter, n_pop, r_cross, r_mut):
    # initial population of random bitstring
    pop = [randint(0, 2, n_bits*len(bounds)).tolist() for _ in range(n_pop)]
    # keep track of best solution
    best, best_eval = 0, objective(decode(bounds, n_bits, pop[0]))
    # enumerate generations
    for gen in range(n_iter):
        # decode population
        decoded = [decode(bounds, n_bits, p) for p in pop]
        # evaluate all candidates in the population
        scores = [objective(d) for d in decoded]
        # check for new best solution
        for i in range(n_pop):
            if scores[i] < best_eval:
                best, best_eval = pop[i], scores[i]
                print(">%d, new best f(%s) = %f" % (gen,  decoded[i], scores[i]))
        # select parents
        selected = [selection(pop, scores) for _ in range(n_pop)]
        # create the next generation
        children = list()
        for i in range(0, n_pop, 2):
            # get selected parents in pairs
            p1, p2 = selected[i], selected[i+1]
            # crossover and mutation
            for c in crossover(p1, p2, r_cross):
                # mutation
                mutation(c, r_mut)
                # store for next generation
                children.append(c)
        # replace population
        pop = children
    return [best, best_eval]


bounds = [x, y]

n_iter = 100

n_bits = 16

n_pop = 100

r_cross = 0.9

r_mut = 1.0 / (float(n_bits) * len(bounds))

best, score = genetic_algorithm(objective, bounds, n_bits, n_iter, n_pop, r_cross, r_mut)
print('Done!')
decoded = decode(bounds, n_bits, best)
print('f(%s) = %f' % (decoded, score))
# Out:
# >0, new best f([array([-12.23664553]), array([-1517.4283129])]) = 2302738.420297
# >0, new best f([array([-12.26172727]), array([-1517.03207392])]) = 2301536.663266
# >2, new best f([array([-12.32127033]), array([-1517.03034391])]) = 2301532.878042
# >3, new best f([array([-12.27382966]), array([-1517.03069429])]) = 2301532.774316
# >4, new best f([array([-12.27397321]), array([-1517.0306067])]) = 2301532.512069
# >5, new best f([array([-12.21454902]), array([-1517.03067239])]) = 2301531.256187
# >5, new best f([array([-12.21502226]), array([-1517.0306067])]) = 2301531.068420
# >6, new best f([array([-12.20483077]), array([-1517.0306067])]) = 2301530.819545
# >6, new best f([array([-12.19282706]), array([-1517.0306067])]) = 2301530.526683
# >6, new best f([array([-12.18653812]), array([-1517.0306067])]) = 2301530.373362
# >7, new best f([array([-12.1861703]), array([-1517.0306067])]) = 2301530.364397
# >8, new best f([array([-12.18646635]), array([-1517.0305848])]) = 2301530.305170
# >8, new best f([array([-12.19495776]), array([-1517.03023441])]) = 2301529.449121
# >9, new best f([array([-12.18594153]), array([-1517.03025631])]) = 2301529.295739
# >13, new best f([array([-12.1836]), array([-1517.03023441])]) = 2301529.172235
# >17, new best f([array([-12.18336001]), array([-1517.03023441])]) = 2301529.166387
# >19, new best f([array([-12.18328375]), array([-1517.03023441])]) = 2301529.164529
# >22, new best f([array([-12.18326581]), array([-1517.03023441])]) = 2301529.164092
# >24, new best f([array([-12.18326357]), array([-1517.03023441])]) = 2301529.164037
# Done!
# f([array([-12.18326357]), array([-1517.03023441])]) = 2301529.164037

# %%
x1=decoded[0]
x2=decoded[1]

# %% [markdown]
# -----------------

# %% [markdown]
# x1
# x2

# %%
print(x1)
print(x2)
# Out:
# [-12.18326357]
# [-1517.03023441]
